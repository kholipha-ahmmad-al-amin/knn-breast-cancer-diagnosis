# %% [markdown]
# ## Author**Kholipha Ahmmad Al-Amin**Software Engineer, SaaS Founder, and AI/Data Practitioner from Dhaka, Bangladesh.Portfolio: https://kholipha-ahmmad-al-amin.equisaas-bd.comGitHub: https://github.com/kholipha-ahmmad-al-aminLinkedIn: https://www.linkedin.com/in/kholipha-ahmmad-al-amin

# %% [markdown]
# <a href="https://colab.research.google.com/github/anms5519/KNN---Breast-Cancer-Diagnosis/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_csv('/content/2025-03-12Breast_Cancer_Diagnostic.csv', index_col=0)
if 'Unnamed: 32' in df.columns:
    df = df.drop('Unnamed: 32', axis=1)
print("Dataset Head:")
print(df.head())
# Out:
# Dataset Head:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# ...

# %%
target = df['diagnosis']
features = df.drop('diagnosis', axis=1)
if features.isnull().sum().sum() > 0:
    print("Missing values found in features. Imputing using median values.")
    features = features.fillna(features.median())
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
df_scaled = pd.DataFrame(scaled_features, columns=features.columns)
print("\nScaled Features Head:")
print(df_scaled.head())
# Out:
# Scaled Features Head:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
# ...

# %%
if df.isnull().sum().sum() > 0:
    df.fillna(df.median(), inplace=True)
    print("\nMissing values filled with median.")
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
sns.histplot(df["radius_mean"], kde=True, bins=20, color="blue")
plt.title("Distribution of Radius Mean")
plt.subplot(2, 2, 2)
sns.histplot(df["texture_mean"], kde=True, bins=20, color="green")
plt.title("Distribution of Texture Mean")
plt.subplot(2, 2, 3)
sns.boxplot(x=df["diagnosis"], y=df["radius_mean"], palette="coolwarm")
plt.title("Radius Mean by Diagnosis")
plt.subplot(2, 2, 4)
sns.boxplot(x=df["diagnosis"], y=df["texture_mean"], palette="coolwarm")
plt.title("Texture Mean by Diagnosis")
plt.tight_layout()
plt.savefig("eda_summary.png", dpi=1200)
plt.show()

# %%
predictions = knn.predict(X_test)
predictions
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'M', 'M', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'M', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B'], dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    scaled_features, target, test_size=0.30, random_state=42
)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
conf_mat = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print("\nAccuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_mat)
print("\nClassification Report:\n", report)
# Out:
# Accuracy: 0.9590643274853801
#
# Confusion Matrix:
#  [[105   3]
#  [  4  59]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.96      0.97      0.97       108
#            M       0.95      0.94      0.94        63
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
plt.figure(figsize=(8,6))
sns.heatmap(conf_mat, annot=True, fmt="d", cmap="Blues",
            xticklabels=sorted(target.unique()),
            yticklabels=sorted(target.unique()))
plt.title("Confusion Matrix\n"
          "KNN - Breast Cancer Diagnosis\n"
          "Student: Kholipha Ahmmad Al-Amin, ID: 221-0217-203\n"
          "Course: Microprocessor & Assembly Languages (CSE-317/318, Section-01)\n"
          "Instructor: Mahmudur Rahman Roni\n"
          "Atish Dipankar University of Science & Technology", fontsize=10)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.savefig("confusion_matrix.png", dpi=1200)
plt.show()
